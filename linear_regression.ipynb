# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import r2_score

# %% [markdown]
# ## Load the data you receive into a Pandas DataFrame

# %%
lol = pd.read_csv('high_diamond_ranked_10min.csv')
lol
# Out:
#           gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  \
# 0     4519157822         0               28                   2
# 1     4523371949         0               12                   1
# 2     4521474530         0               15                   0
# 3     4524384067         0               43                   1
# 4     4436033771         0               75                   4
# ...          ...       ...              ...                 ...
# 9874  4527873286         1               17                   2
# 9875  4527797466         1               54                   0
# 9876  4527713716         0               23                   1
# 9877  4527628313         0               14                   4
# 9878  4523772935         1               18                   0
#
#       blueFirstBlood  blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# 0                  1          9           6           11                  0
# ...

# %% [markdown]
# ## Show the first five rows of the data set

# %%
lol.head(5)
# Out:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
# 3  4524384067         0               43                   1               0
# 4  4436033771         0               75                   4               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  ...  \
# 0          9           6           11                  0            0  ...
# 1          5           5            5                  0            0  ...
# 2          7          11            4                  1            1  ...
# 3          4           5            5                  1            0  ...
# 4          6           6            6                  0            0  ...
#
# ...

# %% [markdown]
# ## Show the description and the info of the data set

# %%
lol.describe()
# Out:
#              gameId     blueWins  blueWardsPlaced  blueWardsDestroyed  \
# count  9.879000e+03  9879.000000      9879.000000         9879.000000
# mean   4.500084e+09     0.499038        22.288288            2.824881
# std    2.757328e+07     0.500024        18.019177            2.174998
# min    4.295358e+09     0.000000         5.000000            0.000000
# 25%    4.483301e+09     0.000000        14.000000            1.000000
# 50%    4.510920e+09     0.000000        16.000000            3.000000
# 75%    4.521733e+09     1.000000        20.000000            4.000000
# max    4.527991e+09     1.000000       250.000000           27.000000
#
#        blueFirstBlood    blueKills   blueDeaths  blueAssists  \
# count     9879.000000  9879.000000  9879.000000  9879.000000
# mean         0.504808     6.183925     6.137666     6.645106
# std          0.500002     3.011028     2.933818     4.064520
# min          0.000000     0.000000     0.000000     0.000000
# ...

# %%
lol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9879 entries, 0 to 9878
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   gameId                        9879 non-null   int64
#  1   blueWins                      9879 non-null   int64
#  2   blueWardsPlaced               9879 non-null   int64
#  3   blueWardsDestroyed            9879 non-null   int64
#  4   blueFirstBlood                9879 non-null   int64
#  5   blueKills                     9879 non-null   int64
#  6   blueDeaths                    9879 non-null   int64
#  7   blueAssists                   9879 non-null   int64
#  8   blueEliteMonsters             9879 non-null   int64
#  9   blueDragons                   9879 non-null   int64
#  10  blueHeralds                   9879 non-null   int64
#  11  blueTowersDestroyed           9879 non-null   int64
#  12  blueTotalGold                 9879 non-null   int64
# ...

# %% [markdown]
# ## Using a regression model, split your data into train and test data

# %%
# y = lol['blueWardsPlaced'].values
# X = lol['blueDeaths'].values
X = lol['redDeaths'].values
y = lol['blueKills'].values
print(r2_score(X, y))
print(X)
X.shape
print(y)
y.shape
# Out:
# 1.0
# [9 5 7 ... 6 2 6]
# [9 5 7 ... 6 2 6]
# (9879,)

# %%
X = X.reshape(-1,1)
X
# Out:
# array([[9],
#        [5],
#        [7],
#        ...,
#        [6],
#        [2],
#        [6]])

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=100)
print(f"X_train shape {x_train.shape}")
print(f"y_train shape {y_train.shape}")
print(f"x_test shape {x_test.shape}")
print(f"y_test shape {y_test.shape}")
print(y_test)
# Out:
# X_train shape (7903, 1)
# y_train shape (7903,)
# x_test shape (1976, 1)
# y_test shape (1976,)
# [ 8  3  9 ... 11  4  4]

# %%
# %matplotlib inline
plt.scatter(x_train, y_train, color='red')
plt.xlabel('Red Deaths')
plt.ylabel('Blue Kills')
plt.title('Training Data')
plt.show()
# plt.plot()

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)
y_predict = lm.predict(x_test)
print(f"Train accuracy {round(lm.score(x_train, y_train)*100,2)}%")
print(f"Test accuracy {round(lm.score(x_test, y_test)*100, 2)}%")
print(lm.score(x_train, y_train))
# Out:
# Train accuracy 100.0%
# Test accuracy 100.0%
# 1.0

# %%
plt.scatter(x_train, y_train, color='red')
plt.plot(x_test, y_predict)
plt.xlabel("Red Deaths")
plt.ylabel("Blue Kills")
plt.title("Trained Model Plot")
plt.plot()
plt.show()

# %% [markdown]
# * Draw at least three conclusions from your regression model
#     1. There is a correlation between blue kills and red deaths...which makes perfect sense. Each time the red time dies, the blue team gets a kill
#     1. The two variables selected are obvios but they at least show the linear regression model works
#     1. Red deaths increase as blue kills increase
